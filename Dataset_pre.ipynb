# %% [markdown]
# This section contains the preprocessing of the data.

# %%
import pandas as pd # type: ignore
import numpy as np # type: ignore
from sklearn.preprocessing import MinMaxScaler

# %%
dataset=pd.read_csv('Wednesday-workingHours.pcap_ISCX.csv')

# %% [markdown]
# First we should drop the redundant records.

# %%
newdata=dataset.drop_duplicates()
newdata.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 80           38308                   1
# 1                389             479                  11
# 2                 88            1095                  10
# 3                389           15206                  17
# 4                 88            1092                   9
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        1                            6
# 1                        5                          172
# 2                        6                         3150
# 3                       12                         3452
# 4                        6                         3150
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             6                       6
# 1                           326                      79
# 2                          3150                    1575
# 3                          6660                    1313
# 4                          3152                    1575
#
#     Fwd Packet Length Min   Fwd Packet Length Mean   Fwd Packet Length Std  \
# 0                       6                 6.000000                0.000000
# 1                       0                15.636364               31.449238
# 2                       0               315.000000              632.561635
# 3                       0               203.058823              425.778474
# 4                       0               350.000000              694.509719
#
#    ...   min_seg_size_forward  Active Mean   Active Std   Active Max  \
# 0  ...                     20          0.0          0.0            0
# 1  ...                     32          0.0          0.0            0
# 2  ...                     32          0.0          0.0            0
# 3  ...                     32          0.0          0.0            0
# 4  ...                     32          0.0          0.0            0
#
#     Active Min  Idle Mean   Idle Std   Idle Max   Idle Min   Label
# 0            0        0.0        0.0          0          0  BENIGN
# 1            0        0.0        0.0          0          0  BENIGN
# 2            0        0.0        0.0          0          0  BENIGN
# 3            0        0.0        0.0          0          0  BENIGN
# 4            0        0.0        0.0          0          0  BENIGN
#
# [5 rows x 79 columns]

# %% [markdown]
# Now let's move on to handling null values.

# %%
final_data=newdata.dropna()
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 610733 entries, 0 to 692702
# Data columns (total 79 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0    Destination Port             610733 non-null  int64
#  1    Flow Duration                610733 non-null  int64
#  2    Total Fwd Packets            610733 non-null  int64
#  3    Total Backward Packets       610733 non-null  int64
#  4   Total Length of Fwd Packets   610733 non-null  int64
#  5    Total Length of Bwd Packets  610733 non-null  int64
#  6    Fwd Packet Length Max        610733 non-null  int64
#  7    Fwd Packet Length Min        610733 non-null  int64
#  8    Fwd Packet Length Mean       610733 non-null  float64
#  9    Fwd Packet Length Std        610733 non-null  float64
#  10  Bwd Packet Length Max         610733 non-null  int64
#  11   Bwd Packet Length Min        610733 non-null  int64
#  12   Bwd Packet Length Mean       610733 non-null  float64
#  13   Bwd Packet Length Std        610733 non-null  float64
#  14  Flow Bytes/s                  610733 non-null  float64
#  15   Flow Packets/s               610733 non-null  float64
#  16   Flow IAT Mean                610733 non-null  float64
#  17   Flow IAT Std                 610733 non-null  float64
#  18   Flow IAT Max                 610733 non-null  int64
#  19   Flow IAT Min                 610733 non-null  int64
#  20  Fwd IAT Total                 610733 non-null  int64
#  21   Fwd IAT Mean                 610733 non-null  float64
#  22   Fwd IAT Std                  610733 non-null  float64
#  23   Fwd IAT Max                  610733 non-null  int64
#  24   Fwd IAT Min                  610733 non-null  int64
#  25  Bwd IAT Total                 610733 non-null  int64
#  26   Bwd IAT Mean                 610733 non-null  float64
#  27   Bwd IAT Std                  610733 non-null  float64
#  28   Bwd IAT Max                  610733 non-null  int64
#  29   Bwd IAT Min                  610733 non-null  int64
#  30  Fwd PSH Flags                 610733 non-null  int64
#  31   Bwd PSH Flags                610733 non-null  int64
#  32   Fwd URG Flags                610733 non-null  int64
#  33   Bwd URG Flags                610733 non-null  int64
#  34   Fwd Header Length            610733 non-null  int64
#  35   Bwd Header Length            610733 non-null  int64
#  36  Fwd Packets/s                 610733 non-null  float64
#  37   Bwd Packets/s                610733 non-null  float64
#  38   Min Packet Length            610733 non-null  int64
#  39   Max Packet Length            610733 non-null  int64
#  40   Packet Length Mean           610733 non-null  float64
#  41   Packet Length Std            610733 non-null  float64
#  42   Packet Length Variance       610733 non-null  float64
#  43  FIN Flag Count                610733 non-null  int64
#  44   SYN Flag Count               610733 non-null  int64
#  45   RST Flag Count               610733 non-null  int64
#  46   PSH Flag Count               610733 non-null  int64
#  47   ACK Flag Count               610733 non-null  int64
#  48   URG Flag Count               610733 non-null  int64
#  49   CWE Flag Count               610733 non-null  int64
#  50   ECE Flag Count               610733 non-null  int64
#  51   Down/Up Ratio                610733 non-null  int64
#  52   Average Packet Size          610733 non-null  float64
#  53   Avg Fwd Segment Size         610733 non-null  float64
#  54   Avg Bwd Segment Size         610733 non-null  float64
#  55   Fwd Header Length.1          610733 non-null  int64
#  56  Fwd Avg Bytes/Bulk            610733 non-null  int64
#  57   Fwd Avg Packets/Bulk         610733 non-null  int64
#  58   Fwd Avg Bulk Rate            610733 non-null  int64
#  59   Bwd Avg Bytes/Bulk           610733 non-null  int64
#  60   Bwd Avg Packets/Bulk         610733 non-null  int64
#  61  Bwd Avg Bulk Rate             610733 non-null  int64
#  62  Subflow Fwd Packets           610733 non-null  int64
#  63   Subflow Fwd Bytes            610733 non-null  int64
#  64   Subflow Bwd Packets          610733 non-null  int64
#  65   Subflow Bwd Bytes            610733 non-null  int64
#  66  Init_Win_bytes_forward        610733 non-null  int64
#  67   Init_Win_bytes_backward      610733 non-null  int64
#  68   act_data_pkt_fwd             610733 non-null  int64
#  69   min_seg_size_forward         610733 non-null  int64
#  70  Active Mean                   610733 non-null  float64
#  71   Active Std                   610733 non-null  float64
#  72   Active Max                   610733 non-null  int64
#  73   Active Min                   610733 non-null  int64
#  74  Idle Mean                     610733 non-null  float64
#  75   Idle Std                     610733 non-null  float64
#  76   Idle Max                     610733 non-null  int64
#  77   Idle Min                     610733 non-null  int64
#  78   Label                        610733 non-null  object
# dtypes: float64(24), int64(54), object(1)
# memory usage: 372.8+ MB

# %% [markdown]
# Our model will only need to detect DoS attacks so we are eliminating the 'heartbleed' labeled rows.

# %%
mask=final_data[' Label'] == 'Heartbleed'
htbleed=final_data[mask]
print(htbleed)
# Out:
#          Destination Port   Flow Duration   Total Fwd Packets  \
# 597130                444       119302728                2685
# 597175                444       119262215                2792
# 597209                444       119261118                2794
# 597265                444       119260295                2791
# 597277                444       119297996                2782
# 597510                444       119259886                2782
# 597536                444       119259012                2801
# 597722                444       119257653                2802
# 597807                444       119299621                2805
# 597813                444       119296592                2797
# 597825                444        24719667                 590
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 597130                     1729                         8299
# 597175                     2110                        13712
# 597209                     2130                        12264
# 597265                     2114                        13712
# 597277                     2089                         9368
# 597510                     2091                        12264
# 597536                     2069                        12264
# 597722                     2067                        20858
# 597807                     2028                        13712
# 597813                     2006                        13712
# 597825                      436                         7442
#
#          Total Length of Bwd Packets   Fwd Packet Length Max  \
# 597130                       7556917                     517
# 597175                       7878135                    5792
# 597209                       7879536                    4344
# 597265                       7878088                    5792
# 597277                       7882432                    1448
# 597510                       7879536                    4344
# 597536                       7879536                    4344
# 597722                       7812389                    5792
# 597807                       7878627                    5792
# 597813                       7878088                    5792
# 597825                       1636683                    5792
#
#          Fwd Packet Length Min   Fwd Packet Length Mean  \
# 597130                       0                 3.090875
# 597175                       0                 4.911175
# 597209                       0                 4.389406
# 597265                       0                 4.912934
# 597277                       0                 3.367362
# 597510                       0                 4.408339
# 597536                       0                 4.378436
# 597722                       0                 7.443969
# 597807                       0                 4.888414
# 597813                       0                 4.902395
# 597825                       0                12.613559
#
#          Fwd Packet Length Std  ...   min_seg_size_forward  Active Mean  \
# 597130               16.858421  ...                     32       2217.0
# 597175              110.376448  ...                     32          0.0
# 597209               83.211635  ...                     32          0.0
# 597265              110.396187  ...                     32          0.0
# 597277               30.505030  ...                     32          0.0
# 597510               83.390470  ...                     32          0.0
# 597536               83.107845  ...                     32          0.0
# 597722              126.045811  ...                     32          0.0
# 597807              110.120790  ...                     32          0.0
# 597813              110.277907  ...                     32          0.0
# 597825              238.708658  ...                     32          0.0
#
#          Active Std   Active Max   Active Min  Idle Mean   Idle Std  \
# 597130          0.0         2217         2217  5024984.0        0.0
# 597175          0.0            0            0        0.0        0.0
# 597209          0.0            0            0        0.0        0.0
# 597265          0.0            0            0        0.0        0.0
# 597277          0.0            0            0        0.0        0.0
# 597510          0.0            0            0        0.0        0.0
# 597536          0.0            0            0        0.0        0.0
# 597722          0.0            0            0        0.0        0.0
# 597807          0.0            0            0        0.0        0.0
# 597813          0.0            0            0        0.0        0.0
# 597825          0.0            0            0        0.0        0.0
#
#          Idle Max   Idle Min       Label
# 597130    5024984    5024984  Heartbleed
# 597175          0          0  Heartbleed
# 597209          0          0  Heartbleed
# 597265          0          0  Heartbleed
# 597277          0          0  Heartbleed
# 597510          0          0  Heartbleed
# 597536          0          0  Heartbleed
# 597722          0          0  Heartbleed
# 597807          0          0  Heartbleed
# 597813          0          0  Heartbleed
# 597825          0          0  Heartbleed
#
# [11 rows x 79 columns]

# %%
dt=final_data[~mask]
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 610722 entries, 0 to 692702
# Data columns (total 79 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0    Destination Port             610722 non-null  int64
#  1    Flow Duration                610722 non-null  int64
#  2    Total Fwd Packets            610722 non-null  int64
#  3    Total Backward Packets       610722 non-null  int64
#  4   Total Length of Fwd Packets   610722 non-null  int64
#  5    Total Length of Bwd Packets  610722 non-null  int64
#  6    Fwd Packet Length Max        610722 non-null  int64
#  7    Fwd Packet Length Min        610722 non-null  int64
#  8    Fwd Packet Length Mean       610722 non-null  float64
#  9    Fwd Packet Length Std        610722 non-null  float64
#  10  Bwd Packet Length Max         610722 non-null  int64
#  11   Bwd Packet Length Min        610722 non-null  int64
#  12   Bwd Packet Length Mean       610722 non-null  float64
#  13   Bwd Packet Length Std        610722 non-null  float64
#  14  Flow Bytes/s                  610722 non-null  float64
#  15   Flow Packets/s               610722 non-null  float64
#  16   Flow IAT Mean                610722 non-null  float64
#  17   Flow IAT Std                 610722 non-null  float64
#  18   Flow IAT Max                 610722 non-null  int64
#  19   Flow IAT Min                 610722 non-null  int64
#  20  Fwd IAT Total                 610722 non-null  int64
#  21   Fwd IAT Mean                 610722 non-null  float64
#  22   Fwd IAT Std                  610722 non-null  float64
#  23   Fwd IAT Max                  610722 non-null  int64
#  24   Fwd IAT Min                  610722 non-null  int64
#  25  Bwd IAT Total                 610722 non-null  int64
#  26   Bwd IAT Mean                 610722 non-null  float64
#  27   Bwd IAT Std                  610722 non-null  float64
#  28   Bwd IAT Max                  610722 non-null  int64
#  29   Bwd IAT Min                  610722 non-null  int64
#  30  Fwd PSH Flags                 610722 non-null  int64
#  31   Bwd PSH Flags                610722 non-null  int64
#  32   Fwd URG Flags                610722 non-null  int64
#  33   Bwd URG Flags                610722 non-null  int64
#  34   Fwd Header Length            610722 non-null  int64
#  35   Bwd Header Length            610722 non-null  int64
#  36  Fwd Packets/s                 610722 non-null  float64
#  37   Bwd Packets/s                610722 non-null  float64
#  38   Min Packet Length            610722 non-null  int64
#  39   Max Packet Length            610722 non-null  int64
#  40   Packet Length Mean           610722 non-null  float64
#  41   Packet Length Std            610722 non-null  float64
#  42   Packet Length Variance       610722 non-null  float64
#  43  FIN Flag Count                610722 non-null  int64
#  44   SYN Flag Count               610722 non-null  int64
#  45   RST Flag Count               610722 non-null  int64
#  46   PSH Flag Count               610722 non-null  int64
#  47   ACK Flag Count               610722 non-null  int64
#  48   URG Flag Count               610722 non-null  int64
#  49   CWE Flag Count               610722 non-null  int64
#  50   ECE Flag Count               610722 non-null  int64
#  51   Down/Up Ratio                610722 non-null  int64
#  52   Average Packet Size          610722 non-null  float64
#  53   Avg Fwd Segment Size         610722 non-null  float64
#  54   Avg Bwd Segment Size         610722 non-null  float64
#  55   Fwd Header Length.1          610722 non-null  int64
#  56  Fwd Avg Bytes/Bulk            610722 non-null  int64
#  57   Fwd Avg Packets/Bulk         610722 non-null  int64
#  58   Fwd Avg Bulk Rate            610722 non-null  int64
#  59   Bwd Avg Bytes/Bulk           610722 non-null  int64
#  60   Bwd Avg Packets/Bulk         610722 non-null  int64
#  61  Bwd Avg Bulk Rate             610722 non-null  int64
#  62  Subflow Fwd Packets           610722 non-null  int64
#  63   Subflow Fwd Bytes            610722 non-null  int64
#  64   Subflow Bwd Packets          610722 non-null  int64
#  65   Subflow Bwd Bytes            610722 non-null  int64
#  66  Init_Win_bytes_forward        610722 non-null  int64
#  67   Init_Win_bytes_backward      610722 non-null  int64
#  68   act_data_pkt_fwd             610722 non-null  int64
#  69   min_seg_size_forward         610722 non-null  int64
#  70  Active Mean                   610722 non-null  float64
#  71   Active Std                   610722 non-null  float64
#  72   Active Max                   610722 non-null  int64
#  73   Active Min                   610722 non-null  int64
#  74  Idle Mean                     610722 non-null  float64
#  75   Idle Std                     610722 non-null  float64
#  76   Idle Max                     610722 non-null  int64
#  77   Idle Min                     610722 non-null  int64
#  78   Label                        610722 non-null  object
# dtypes: float64(24), int64(54), object(1)
# memory usage: 372.8+ MB

# %% [markdown]
# We should transform the categorical data in our set, the 'Label' column contains the labels of the packets traced, we give 0 value to BENIGN labels and 1 to all other DoS labels.

# %%
dt[' Label']=dt[" Label"].map({'BENIGN':0,'DoS slowloris':1, 'DoS Slowhttptest':1, 'DoS Hulk':1, 'DoS GoldenEye':1 })
dt[' Label'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 610722 entries, 0 to 692702
# Series name:  Label
# Non-Null Count   Dtype
# --------------   -----
# 610722 non-null  int64
# dtypes: int64(1)
# memory usage: 9.3 MB
# C:\Users\DALIDATECH\AppData\Local\Temp\ipykernel_21752\2214938906.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt[' Label']=dt[" Label"].map({'BENIGN':0,'DoS slowloris':1, 'DoS Slowhttptest':1, 'DoS Hulk':1, 'DoS GoldenEye':1 })

# %% [markdown]
# Let's now remove the infinite values in our dataset.

# %%
inf_mask=np.isinf(dt).any(axis=1)
dtt=dt[~inf_mask]
rows_with_inf_values = dtt[inf_mask]
rows_with_inf_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 79 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0    Destination Port             0 non-null      int64
#  1    Flow Duration                0 non-null      int64
#  2    Total Fwd Packets            0 non-null      int64
#  3    Total Backward Packets       0 non-null      int64
#  4   Total Length of Fwd Packets   0 non-null      int64
#  5    Total Length of Bwd Packets  0 non-null      int64
#  6    Fwd Packet Length Max        0 non-null      int64
#  7    Fwd Packet Length Min        0 non-null      int64
#  8    Fwd Packet Length Mean       0 non-null      float64
#  9    Fwd Packet Length Std        0 non-null      float64
#  10  Bwd Packet Length Max         0 non-null      int64
#  11   Bwd Packet Length Min        0 non-null      int64
#  12   Bwd Packet Length Mean       0 non-null      float64
#  13   Bwd Packet Length Std        0 non-null      float64
#  14  Flow Bytes/s                  0 non-null      float64
#  15   Flow Packets/s               0 non-null      float64
#  16   Flow IAT Mean                0 non-null      float64
#  17   Flow IAT Std                 0 non-null      float64
#  18   Flow IAT Max                 0 non-null      int64
#  19   Flow IAT Min                 0 non-null      int64
#  20  Fwd IAT Total                 0 non-null      int64
#  21   Fwd IAT Mean                 0 non-null      float64
#  22   Fwd IAT Std                  0 non-null      float64
#  23   Fwd IAT Max                  0 non-null      int64
#  24   Fwd IAT Min                  0 non-null      int64
#  25  Bwd IAT Total                 0 non-null      int64
#  26   Bwd IAT Mean                 0 non-null      float64
#  27   Bwd IAT Std                  0 non-null      float64
#  28   Bwd IAT Max                  0 non-null      int64
#  29   Bwd IAT Min                  0 non-null      int64
#  30  Fwd PSH Flags                 0 non-null      int64
#  31   Bwd PSH Flags                0 non-null      int64
#  32   Fwd URG Flags                0 non-null      int64
#  33   Bwd URG Flags                0 non-null      int64
#  34   Fwd Header Length            0 non-null      int64
#  35   Bwd Header Length            0 non-null      int64
#  36  Fwd Packets/s                 0 non-null      float64
#  37   Bwd Packets/s                0 non-null      float64
#  38   Min Packet Length            0 non-null      int64
#  39   Max Packet Length            0 non-null      int64
#  40   Packet Length Mean           0 non-null      float64
#  41   Packet Length Std            0 non-null      float64
#  42   Packet Length Variance       0 non-null      float64
#  43  FIN Flag Count                0 non-null      int64
#  44   SYN Flag Count               0 non-null      int64
#  45   RST Flag Count               0 non-null      int64
#  46   PSH Flag Count               0 non-null      int64
#  47   ACK Flag Count               0 non-null      int64
#  48   URG Flag Count               0 non-null      int64
#  49   CWE Flag Count               0 non-null      int64
#  50   ECE Flag Count               0 non-null      int64
#  51   Down/Up Ratio                0 non-null      int64
#  52   Average Packet Size          0 non-null      float64
#  53   Avg Fwd Segment Size         0 non-null      float64
#  54   Avg Bwd Segment Size         0 non-null      float64
#  55   Fwd Header Length.1          0 non-null      int64
#  56  Fwd Avg Bytes/Bulk            0 non-null      int64
#  57   Fwd Avg Packets/Bulk         0 non-null      int64
#  58   Fwd Avg Bulk Rate            0 non-null      int64
#  59   Bwd Avg Bytes/Bulk           0 non-null      int64
#  60   Bwd Avg Packets/Bulk         0 non-null      int64
#  61  Bwd Avg Bulk Rate             0 non-null      int64
#  62  Subflow Fwd Packets           0 non-null      int64
#  63   Subflow Fwd Bytes            0 non-null      int64
#  64   Subflow Bwd Packets          0 non-null      int64
#  65   Subflow Bwd Bytes            0 non-null      int64
#  66  Init_Win_bytes_forward        0 non-null      int64
#  67   Init_Win_bytes_backward      0 non-null      int64
#  68   act_data_pkt_fwd             0 non-null      int64
#  69   min_seg_size_forward         0 non-null      int64
#  70  Active Mean                   0 non-null      float64
#  71   Active Std                   0 non-null      float64
#  72   Active Max                   0 non-null      int64
#  73   Active Min                   0 non-null      int64
#  74  Idle Mean                     0 non-null      float64
#  75   Idle Std                     0 non-null      float64
#  76   Idle Max                     0 non-null      int64
#  77   Idle Min                     0 non-null      int64
#  78   Label                        0 non-null      int64
# dtypes: float64(24), int64(55)
# memory usage: 0.0 bytes
# C:\Users\DALIDATECH\AppData\Local\Temp\ipykernel_21752\2132310262.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   rows_with_inf_values = dtt[inf_mask]

# %% [markdown]
# Scaling the data to make the learning easier for our model.

# %%
scaler = MinMaxScaler()
dtt_normalized=scaler.fit_transform(dtt)
dtt.head()
dtt.tail()
# Out:
#          Destination Port   Flow Duration   Total Fwd Packets  \
# 692698                 53           32215                   4
# 692699                 53             324                   2
# 692700              58030              82                   2
# 692701                 53         1048635                   6
# 692702                 53           94939                   4
#
#          Total Backward Packets  Total Length of Fwd Packets  \
# 692698                        2                          112
# 692699                        2                           84
# 692700                        1                           31
# 692701                        2                          192
# 692702                        2                          188
#
#          Total Length of Bwd Packets   Fwd Packet Length Max  \
# 692698                           152                      28
# 692699                           362                      42
# 692700                             6                      31
# 692701                           256                      32
# 692702                           226                      47
#
#          Fwd Packet Length Min   Fwd Packet Length Mean  \
# 692698                      28                     28.0
# 692699                      42                     42.0
# 692700                       0                     15.5
# 692701                      32                     32.0
# 692702                      47                     47.0
#
#          Fwd Packet Length Std  ...   min_seg_size_forward  Active Mean  \
# 692698                 0.00000  ...                     20          0.0
# 692699                 0.00000  ...                     20          0.0
# 692700                21.92031  ...                     32          0.0
# 692701                 0.00000  ...                     20          0.0
# 692702                 0.00000  ...                     20          0.0
#
#          Active Std   Active Max   Active Min  Idle Mean   Idle Std  \
# 692698          0.0            0            0        0.0        0.0
# 692699          0.0            0            0        0.0        0.0
# 692700          0.0            0            0        0.0        0.0
# 692701          0.0            0            0        0.0        0.0
# 692702          0.0            0            0        0.0        0.0
#
#          Idle Max   Idle Min   Label
# 692698          0          0       0
# 692699          0          0       0
# 692700          0          0       0
# 692701          0          0       0
# 692702          0          0       0
#
# [5 rows x 79 columns]

# %% [markdown]
# Finally we save our modified dataset to a csv file.

# %%
dtt.to_csv('dt.csv', index=False)
